# %%
import numpy as np 
import pandas as pd

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# Merge them together 
df_all = pd.concat([df_train, df_test], axis = 0)

# %%
df_all.shape
# Out:
# (500000, 32)

# %%
 asfd
